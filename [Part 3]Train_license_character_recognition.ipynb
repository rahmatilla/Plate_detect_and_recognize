# %% [markdown]
# #### This notebook is used to train a character recongition from input image using MobileNets

# %%
# ignore warning 
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from keras.preprocessing.image import ImageDataGenerator
from keras.applications import MobileNetV2
from keras.layers import AveragePooling2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import model_from_json
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import glob
import numpy as np

# %% [markdown]
# ### Visualize dataset

# %%
dataset_paths = glob.glob("DATASET_2/**/*.jpg")

cols=4
rows=3
fig = plt.figure(figsize=(10,8))
plt.rcParams.update({"font.size":14})
grid = gridspec.GridSpec(ncols=cols,nrows=rows,figure=fig)

# create a random list of images will be displayed
np.random.seed(45)
rand = np.random.randint(0,len(dataset_paths),size=(cols*rows))

# Plot image
for i in range(cols*rows):
    fig.add_subplot(grid[i])
    image = load_img(dataset_paths[rand[i]])
    label = dataset_paths[rand[i]].split(os.path.sep)[-2]
    plt.title('"{:s}"'.format(label))
    plt.axis(False)
    plt.imshow(image)

plt.savefig("Visualize_dataset.jpg",dpi=300)

# %% [markdown]
# ## Data pre-processing

# %%
# Arange input data and corresponding labels
X=[]
labels=[]

for image_path in dataset_paths:
  label = image_path.split(os.path.sep)[-2]
  image=load_img(image_path,target_size=(80,80))
  image=img_to_array(image)

  X.append(image)
  labels.append(label)

X = np.array(X,dtype="float16")
labels = np.array(labels)

print("[INFO] Find {:d} images with {:d} classes".format(len(X),len(set(labels))))


# perform one-hot encoding on the labels
lb = LabelEncoder()
lb.fit(labels)
labels = lb.transform(labels)
y = to_categorical(labels)

# save label file so we can use in another script
np.save('license_character_classes.npy', lb.classes_)
# Out:
# [INFO] Find 832 images with 36 classes

# %%
# split 10% of data as validation set
(trainX, testX, trainY, testY) = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# %%
# data augumentation
image_gen = ImageDataGenerator(rotation_range=10,
                              width_shift_range=0.1,
                              height_shift_range=0.1,
                              shear_range=0.1,
                              zoom_range=0.1,
                              fill_mode="nearest"
                              )

# %% [markdown]
# ## Initialize MobileNets architecture with pre-trained weight

# %%
# Create our model with pre-trained MobileNetV2 architecture from imagenet
def create_model(lr=1e-4,decay=1e-4/25, training=False,output_shape=y.shape[1]):
    baseModel = MobileNetV2(weights="imagenet", 
                            include_top=False,
                            input_tensor=Input(shape=(80, 80, 3)))

    headModel = baseModel.output
    headModel = AveragePooling2D(pool_size=(3, 3))(headModel)
    headModel = Flatten(name="flatten")(headModel)
    headModel = Dense(128, activation="relu")(headModel)
    headModel = Dropout(0.5)(headModel)
    headModel = Dense(output_shape, activation="softmax")(headModel)
    
    model = Model(inputs=baseModel.input, outputs=headModel)
    
    if training:
        # define trainable lalyer
        for layer in baseModel.layers:
            layer.trainable = True
        # compile model
        optimizer = Adam(lr=lr, decay = decay)
        model.compile(loss="categorical_crossentropy", optimizer=optimizer,metrics=["accuracy"])    
        
    return model

# %%
# initilaize initial hyperparameter
INIT_LR = 1e-4
EPOCHS = 30

model = create_model(lr=INIT_LR, decay=INIT_LR/EPOCHS,training=True)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %% [markdown]
# ## Train model

# %%
BATCH_SIZE = 64

my_checkpointer = [
                EarlyStopping(monitor='val_loss', patience=5, verbose=0),
                ModelCheckpoint(filepath="License_character_recognition_self.h5", verbose=1, save_weights_only=True)
                ]

result = model.fit(image_gen.flow(trainX, trainY, batch_size=BATCH_SIZE), 
                   steps_per_epoch=len(trainX) // BATCH_SIZE, 
                   validation_data=(testX, testY), 
                   validation_steps=len(testX) // BATCH_SIZE, 
                   epochs=EPOCHS, callbacks=my_checkpointer)
# Out:
# Epoch 1/60
# 22/22 [==============================] - 34s 2s/step - loss: 0.4510 - accuracy: 0.8815 - val_loss: 2.0359 - val_accuracy: 0.5680
#
# Epoch 00001: saving model to License_character_recognition_self.h5
# Epoch 2/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.4212 - accuracy: 0.8948 - val_loss: 1.8103 - val_accuracy: 0.6320
#
# Epoch 00002: saving model to License_character_recognition_self.h5
# Epoch 3/60
# 22/22 [==============================] - 33s 1s/step - loss: 0.3877 - accuracy: 0.9022 - val_loss: 1.6268 - val_accuracy: 0.6560
#
# Epoch 00003: saving model to License_character_recognition_self.h5
# Epoch 4/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.3589 - accuracy: 0.9067 - val_loss: 1.5833 - val_accuracy: 0.6800
#
# Epoch 00004: saving model to License_character_recognition_self.h5
# Epoch 5/60
# 22/22 [==============================] - 34s 2s/step - loss: 0.3085 - accuracy: 0.9247 - val_loss: 1.5258 - val_accuracy: 0.7120
#
# Epoch 00005: saving model to License_character_recognition_self.h5
# Epoch 6/60
# 22/22 [==============================] - 33s 1s/step - loss: 0.2762 - accuracy: 0.9141 - val_loss: 1.5616 - val_accuracy: 0.7040
#
# Epoch 00006: saving model to License_character_recognition_self.h5
# Epoch 7/60
# 22/22 [==============================] - 33s 1s/step - loss: 0.2448 - accuracy: 0.9393 - val_loss: 1.4144 - val_accuracy: 0.7200
#
# Epoch 00007: saving model to License_character_recognition_self.h5
# Epoch 8/60
# 22/22 [==============================] - 33s 1s/step - loss: 0.2993 - accuracy: 0.9185 - val_loss: 1.2868 - val_accuracy: 0.7120
#
# Epoch 00008: saving model to License_character_recognition_self.h5
# Epoch 9/60
# 22/22 [==============================] - 33s 1s/step - loss: 0.2392 - accuracy: 0.9333 - val_loss: 1.1341 - val_accuracy: 0.7520
#
# Epoch 00009: saving model to License_character_recognition_self.h5
# Epoch 10/60
# 22/22 [==============================] - 34s 2s/step - loss: 0.2036 - accuracy: 0.9541 - val_loss: 0.9796 - val_accuracy: 0.7600
#
# Epoch 00010: saving model to License_character_recognition_self.h5
# Epoch 11/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.2257 - accuracy: 0.9319 - val_loss: 0.9217 - val_accuracy: 0.8080
#
# Epoch 00011: saving model to License_character_recognition_self.h5
# Epoch 12/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.2045 - accuracy: 0.9452 - val_loss: 0.8175 - val_accuracy: 0.8160
#
# Epoch 00012: saving model to License_character_recognition_self.h5
# Epoch 13/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.1521 - accuracy: 0.9704 - val_loss: 0.7279 - val_accuracy: 0.8480
#
# Epoch 00013: saving model to License_character_recognition_self.h5
# Epoch 14/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.1599 - accuracy: 0.9659 - val_loss: 0.7012 - val_accuracy: 0.8480
#
# Epoch 00014: saving model to License_character_recognition_self.h5
# Epoch 15/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.1479 - accuracy: 0.9719 - val_loss: 0.7104 - val_accuracy: 0.8240
#
# Epoch 00015: saving model to License_character_recognition_self.h5
# Epoch 16/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.1916 - accuracy: 0.9556 - val_loss: 0.7128 - val_accuracy: 0.8320
#
# Epoch 00016: saving model to License_character_recognition_self.h5
# Epoch 17/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.1524 - accuracy: 0.9570 - val_loss: 0.7655 - val_accuracy: 0.8240
#
# Epoch 00017: saving model to License_character_recognition_self.h5
# Epoch 18/60
# 22/22 [==============================] - 34s 2s/step - loss: 0.1157 - accuracy: 0.9778 - val_loss: 0.6524 - val_accuracy: 0.8560
#
# Epoch 00018: saving model to License_character_recognition_self.h5
# Epoch 19/60
# 22/22 [==============================] - 34s 2s/step - loss: 0.1244 - accuracy: 0.9733 - val_loss: 0.5627 - val_accuracy: 0.8560
#
# Epoch 00019: saving model to License_character_recognition_self.h5
# Epoch 20/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.0996 - accuracy: 0.9763 - val_loss: 0.4518 - val_accuracy: 0.8720
#
# Epoch 00020: saving model to License_character_recognition_self.h5
# Epoch 21/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.1339 - accuracy: 0.9659 - val_loss: 0.4368 - val_accuracy: 0.8720
#
# Epoch 00021: saving model to License_character_recognition_self.h5
# Epoch 22/60
# 22/22 [==============================] - 34s 2s/step - loss: 0.1065 - accuracy: 0.9778 - val_loss: 0.3396 - val_accuracy: 0.8720
#
# Epoch 00022: saving model to License_character_recognition_self.h5
# Epoch 23/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.1090 - accuracy: 0.9689 - val_loss: 0.2375 - val_accuracy: 0.9120
#
# Epoch 00023: saving model to License_character_recognition_self.h5
# Epoch 24/60
# 22/22 [==============================] - 34s 2s/step - loss: 0.0997 - accuracy: 0.9730 - val_loss: 0.1973 - val_accuracy: 0.9200
#
# Epoch 00024: saving model to License_character_recognition_self.h5
# Epoch 25/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.1172 - accuracy: 0.9704 - val_loss: 0.1885 - val_accuracy: 0.9360
#
# Epoch 00025: saving model to License_character_recognition_self.h5
# Epoch 26/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.1268 - accuracy: 0.9674 - val_loss: 0.2371 - val_accuracy: 0.9280
#
# Epoch 00026: saving model to License_character_recognition_self.h5
# Epoch 27/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.1022 - accuracy: 0.9689 - val_loss: 0.2042 - val_accuracy: 0.9280
#
# Epoch 00027: saving model to License_character_recognition_self.h5
# Epoch 28/60
# 22/22 [==============================] - 34s 2s/step - loss: 0.0983 - accuracy: 0.9778 - val_loss: 0.1622 - val_accuracy: 0.9360
#
# Epoch 00028: saving model to License_character_recognition_self.h5
# Epoch 29/60
# 22/22 [==============================] - 34s 2s/step - loss: 0.1052 - accuracy: 0.9704 - val_loss: 0.1097 - val_accuracy: 0.9600
#
# Epoch 00029: saving model to License_character_recognition_self.h5
# Epoch 30/60
# 22/22 [==============================] - 34s 2s/step - loss: 0.0961 - accuracy: 0.9822 - val_loss: 0.1278 - val_accuracy: 0.9600
#
# Epoch 00030: saving model to License_character_recognition_self.h5
# Epoch 31/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.0928 - accuracy: 0.9748 - val_loss: 0.1162 - val_accuracy: 0.9840
#
# Epoch 00031: saving model to License_character_recognition_self.h5
# Epoch 32/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.1009 - accuracy: 0.9719 - val_loss: 0.1138 - val_accuracy: 0.9840
#
# Epoch 00032: saving model to License_character_recognition_self.h5
# Epoch 33/60
# 22/22 [==============================] - 33s 2s/step - loss: 0.1192 - accuracy: 0.9704 - val_loss: 0.1199 - val_accuracy: 0.9680
#
# Epoch 00033: saving model to License_character_recognition_self.h5
# Epoch 34/60
# 22/22 [==============================] - 34s 2s/step - loss: 0.0798 - accuracy: 0.9807 - val_loss: 0.1513 - val_accuracy: 0.9520
#
# Epoch 00034: saving model to License_character_recognition_self.h5

# %% [markdown]
# ## Visualize training result

# %%
fig = plt.figure(figsize=(14,5))
grid=gridspec.GridSpec(ncols=2,nrows=1,figure=fig)
fig.add_subplot(grid[0])
plt.plot(result.history['accuracy'], label='training accuracy')
plt.plot(result.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()

fig.add_subplot(grid[1])
plt.plot(result.history['loss'], label='training loss')
plt.plot(result.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()

#plt.savefig("Training_result.jpg",dpi=300)

# %%
# save model architectur as json file
model_json = model.to_json()
with open("MobileNets_character_recognition_self.json", "w") as json_file:
  json_file.write(model_json)

# %% [markdown]
# ## The End!
